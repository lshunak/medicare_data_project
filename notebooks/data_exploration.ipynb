# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Set display options for better readability
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', 1000)

# %%
# Discover and catalog available data files
data_dir = Path('raw_data')  # Start with raw_data directory

# Check if extracted subdirectory exists and use it if available
extracted_dir = data_dir / 'extracted'
if extracted_dir.exists():
    data_dir = extracted_dir
    print(f"Using extracted data directory: {data_dir.absolute()}")
else:
    print(f"Using raw data directory: {data_dir.absolute()}")
    
if not data_dir.exists():
    print(f"Directory not found: {data_dir.absolute()}")
    print("Please adjust the data_dir path to match your file location")

# Use a generator to find all CSV files recursively
def find_csv_files(directory):
    """Generator that yields CSV files from a directory recursively"""
    for path in Path(directory).rglob('*.csv'):
        yield path

# Use the generator but store results for display purposes
all_csv_files = list(find_csv_files(data_dir))
print(f"Found {len(all_csv_files)} CSV files in the dataset")

# File size calculation can also use a generator approach
def get_file_sizes(files):
    """Generator that yields file paths with their sizes"""
    for file_path in files:
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        yield file_path, size_mb

# Display ALL files with their sizes
print("\nComplete list of all CSV files:")
for i, (file_path, size_mb) in enumerate(get_file_sizes(all_csv_files)):
    print(f"{i+1}. {file_path} - {size_mb:.2f} MB")
# Out:
# Using extracted data directory: /home/liran/Documents/medicare_data_project/raw_data/extracted
# Found 18 CSV files in the dataset
#
# Complete list of all CSV files:
# 1. raw_data/extracted/beneficiary_2019.csv - 3.92 MB
# 2. raw_data/extracted/beneficiary_2021.csv - 4.34 MB
# 3. raw_data/extracted/beneficiary_2020.csv - 4.13 MB
# 4. raw_data/extracted/beneficiary_2022.csv - 4.56 MB
# 5. raw_data/extracted/beneficiary_2015.csv - 3.15 MB
# 6. raw_data/extracted/outpatient.csv - 320.09 MB
# 7. raw_data/extracted/beneficiary_2017.csv - 3.48 MB
# 8. raw_data/extracted/beneficiary_2023.csv - 4.84 MB
# 9. raw_data/extracted/inpatient.csv - 33.89 MB
# 10. raw_data/extracted/beneficiary_2016.csv - 3.31 MB
# 11. raw_data/extracted/carrier.csv - 443.66 MB
# 12. raw_data/extracted/dme.csv - 36.49 MB
# 13. raw_data/extracted/hospice.csv - 4.38 MB
# 14. raw_data/extracted/beneficiary_2018.csv - 3.69 MB
# 15. raw_data/extracted/snf.csv - 9.49 MB
# 16. raw_data/extracted/beneficiary_2025.csv - 3.17 MB
# 17. raw_data/extracted/hha.csv - 2.09 MB
# 18. raw_data/extracted/beneficiary_2024.csv - 5.09 MB

# %%
# Cell 3 (Revised): Determine correct file format and create summary
import pandas as pd
import os
from pathlib import Path

# Let's investigate the first few lines of a file to determine the delimiter
sample_file = all_csv_files[0]
with open(sample_file, 'r', errors='ignore') as f:
    first_line = f.readline().strip()
    second_line = f.readline().strip() if f.readline() else ""
    
print(f"Sample from {sample_file.name}:")
print(f"First line: {first_line[:100]}...")
print(f"Second line: {second_line[:100]}...")

# Check potential delimiters
potential_delimiters = [',', '|', '\t', ';']
delimiter_counts = {}

for delimiter in potential_delimiters:
    delimiter_counts[delimiter] = first_line.count(delimiter)
    
print("\nPotential delimiters detected:")
for delimiter, count in delimiter_counts.items():
    print(f"  '{delimiter}': {count} occurrences")
    
# Determine most likely delimiter
most_likely_delimiter = max(delimiter_counts, key=delimiter_counts.get)
print(f"\nMost likely delimiter: '{most_likely_delimiter}' with {delimiter_counts[most_likely_delimiter]} occurrences")

# Try reading with the detected delimiter
print(f"\nAttempting to read files with '{most_likely_delimiter}' delimiter...")

# Process files with correct delimiter
file_info = []
for file_path in all_csv_files:
    try:
        # Read just the first few rows with detected delimiter
        df_sample = pd.read_csv(file_path, delimiter=most_likely_delimiter, nrows=5)
        
        # Get file size in MB
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        
        file_info.append({
            'filename': file_path.name,
            'directory': str(file_path.parent),
            'columns': len(df_sample.columns),
            'size_mb': round(size_mb, 2),
            'column_sample': list(df_sample.columns[:3])
        })
        print(f"Processed {file_path.name} - {size_mb:.2f} MB with {len(df_sample.columns)} columns")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Create a summary dataframe
files_df = pd.DataFrame(file_info)

# Display the file summary sorted by size
print("\nFile Summary (sorted by size):")
display(files_df[['filename', 'columns', 'size_mb']].sort_values('size_mb', ascending=False))

# Simple categorization function
def get_file_category(filename):
    filename = filename.lower()
    if 'beneficiary' in filename:
        return 'Beneficiary'
    elif any(x in filename for x in ['carrier', 'inpatient', 'outpatient', 'dme', 'hha', 'hospice', 'snf']):
        return 'Claims'
    else:
        return 'Other'
        
# Add simple categorization
files_df['category'] = files_df['filename'].apply(get_file_category)

# Group by category
category_summary = files_df.groupby('category').agg({
    'filename': 'count', 
    'size_mb': 'sum'
}).reset_index()

print("\nFiles by Category:")
display(category_summary)
# Out:
# Sample from beneficiary_2019.csv:
# First line: BENE_ID|STATE_CODE|COUNTY_CD|ZIP_CD|BENE_BIRTH_DT|SEX_IDENT_CD|BENE_RACE_CD|ENTLMT_RSN_ORIG|ENTLMT_R...
# Second line: -10000010254647|01|1410|35756|14-Aug-1990|1|2|1|1|0|0|0||2019|12|12|12|0|0|CME|| |A|29|06-Feb-2014|0...
#
# Potential delimiters detected:
#   ',': 0 occurrences
#   '|': 184 occurrences
#   '	': 0 occurrences
#   ';': 0 occurrences
#
# Most likely delimiter: '|' with 184 occurrences
#
# Attempting to read files with '|' delimiter...
# Processed beneficiary_2019.csv - 3.92 MB with 185 columns
# Processed beneficiary_2021.csv - 4.34 MB with 185 columns
# Processed beneficiary_2020.csv - 4.13 MB with 185 columns
# Processed beneficiary_2022.csv - 4.56 MB with 185 columns
# Processed beneficiary_2015.csv - 3.15 MB with 185 columns
# Processed outpatient.csv - 320.09 MB with 162 columns
# Processed beneficiary_2017.csv - 3.48 MB with 185 columns
# Processed beneficiary_2023.csv - 4.84 MB with 185 columns
# Processed inpatient.csv - 33.89 MB with 197 columns
# Processed beneficiary_2016.csv - 3.31 MB with 185 columns
# Processed carrier.csv - 443.66 MB with 96 columns
# Processed dme.csv - 36.49 MB with 87 columns
# Processed hospice.csv - 4.38 MB with 86 columns
# Processed beneficiary_2018.csv - 3.69 MB with 185 columns
# Processed snf.csv - 9.49 MB with 160 columns
# Processed beneficiary_2025.csv - 3.17 MB with 185 columns
# Processed hha.csv - 2.09 MB with 88 columns
# Processed beneficiary_2024.csv - 5.09 MB with 185 columns
#
# File Summary (sorted by size):
#                 filename  columns  size_mb
# 10           carrier.csv       96   443.66
# 5         outpatient.csv      162   320.09
# 11               dme.csv       87    36.49
# 8          inpatient.csv      197    33.89
# 14               snf.csv      160     9.49
# 17  beneficiary_2024.csv      185     5.09
# 7   beneficiary_2023.csv      185     4.84
# 3   beneficiary_2022.csv      185     4.56
# 12           hospice.csv       86     4.38
# 1   beneficiary_2021.csv      185     4.34
# 2   beneficiary_2020.csv      185     4.13
# 0   beneficiary_2019.csv      185     3.92
# 13  beneficiary_2018.csv      185     3.69
# 6   beneficiary_2017.csv      185     3.48
# 9   beneficiary_2016.csv      185     3.31
# 15  beneficiary_2025.csv      185     3.17
# 4   beneficiary_2015.csv      185     3.15
# 16               hha.csv       88     2.09
# Files by Category:
#       category  filename  size_mb
# 0  Beneficiary        11    43.68
# 1       Claims         7   850.09

# %%
# Cell 4: Basic Data Structure Exploration
print("EXPLORING MEDICARE DATA STRUCTURE")
print("=" * 50)

# Function to analyze file schema
def analyze_schema(file_path, delimiter='|', sample_rows=5):
    """Analyze and print basic schema information for a file"""
    try:
        # Get file size
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        
        # Count total rows (efficiently)
        total_rows = sum(1 for _ in open(file_path, 'r'))
        
        # Read sample to get columns
        df_sample = pd.read_csv(file_path, delimiter=delimiter, nrows=sample_rows)
        
        print(f"\nFile: {file_path.name}")
        print(f"Size: {size_mb:.2f} MB")
        print(f"Total rows: {total_rows:,}")
        print(f"Total columns: {len(df_sample.columns)}")
        
        # Print schema information
        print("\nSchema:")
        schema_info = []
        for col in df_sample.columns:
            # Get data type
            dtype = str(df_sample[col].dtype)
            
            # Get a sample non-null value if available
            sample = str(df_sample[col].dropna().iloc[0]) if not df_sample[col].isna().all() else "NULL"
            if len(sample) > 50:
                sample = sample[:47] + "..."
                
            # Check if all values are the same
            unique_count = df_sample[col].nunique()
            
            schema_info.append({
                'Column': col,
                'Type': dtype,
                'Sample Value': sample,
                'Unique Values': unique_count,
                'Has Nulls': df_sample[col].isna().any()
            })
        
        # Display schema as a table
        schema_df = pd.DataFrame(schema_info)
        display(schema_df)
        
        return total_rows, len(df_sample.columns), df_sample
        
    except Exception as e:
        print(f"Error analyzing {file_path}: {e}")
        return 0, 0, None

# First, get an overview of all files
print("OVERALL DATASET SUMMARY")
print("-" * 50)
file_summary = []

for file_path in all_csv_files:
    try:
        # Get basic info without full schema
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        df_sample = pd.read_csv(file_path, delimiter='|', nrows=1)
        file_summary.append({
            'filename': file_path.name,
            'size_mb': round(size_mb, 2),
            'columns': len(df_sample.columns)
        })
        
    except Exception as e:
        print(f"Error with {file_path.name}: {e}")

# Create summary table
summary_df = pd.DataFrame(file_summary)
print("\nOverall File Summary:")
display(summary_df.sort_values('size_mb', ascending=False))

# Group files by type
def get_file_type(filename):
    filename = filename.lower()
    if 'beneficiary' in filename:
        year = filename.split("_")[-1].split(".")[0] if "_" in filename else "unknown"
        return f"Beneficiary {year}"
    elif 'carrier' in filename:
        return "Carrier Claims"
    elif 'inpatient' in filename:
        return "Inpatient Claims"
    elif 'outpatient' in filename:
        return "Outpatient Claims"
    elif 'dme' in filename:
        return "DME Claims"
    elif 'hha' in filename:
        return "Home Health Claims"
    elif 'hospice' in filename:
        return "Hospice Claims"
    elif 'snf' in filename:
        return "Skilled Nursing Claims"
    else:
        return "Other"

summary_df['file_type'] = summary_df['filename'].apply(get_file_type)
type_summary = summary_df.groupby('file_type').agg({
    'filename': 'count',
    'size_mb': 'sum',
    'columns': 'mean'
}).reset_index()

print("\nFiles by Type:")
display(type_summary.sort_values('size_mb', ascending=False))

# Now, analyze schema for each type of file (one example of each)
print("\n\nDETAILED SCHEMA ANALYSIS")
print("=" * 50)

# Get one example of each file type
file_types = {}
for file_path in all_csv_files:
    file_type = get_file_type(file_path.name)
    if file_type not in file_types:
        file_types[file_type] = file_path

# Analyze schema for each file type
dataframes = {}
for file_type, file_path in file_types.items():
    print(f"\n{'=' * 30}")
    print(f"ANALYZING {file_type.upper()}")
    print(f"{'=' * 30}")
    
    rows, cols, df_sample = analyze_schema(file_path, delimiter='|', sample_rows=10)
    
    # Store sample dataframe for later use
    if df_sample is not None:
        dataframes[file_type] = df_sample
        
        # For the largest files, show just the column names to avoid clutter
        if file_path.name in ['carrier.csv', 'outpatient.csv']:
            print("\nColumns (first 20):")
            for i, col in enumerate(df_sample.columns[:20]):
                print(f"{i+1}. {col}")
            if len(df_sample.columns) > 20:
                print(f"...and {len(df_sample.columns) - 20} more columns")

# Explore potential primary keys and foreign keys
print("\n\nPOTENTIAL JOIN KEYS")
print("=" * 50)

# Look for common ID columns across files
all_id_columns = {}
for file_type, df in dataframes.items():
    # Identify potential ID columns
    id_cols = [col for col in df.columns if 'ID' in col.upper() and 'PROVIDER' not in col.upper()]
    all_id_columns[file_type] = id_cols
    
    print(f"\n{file_type} potential ID columns:")
    for col in id_cols[:5]:
        print(f"  - {col}")
    if len(id_cols) > 5:
        print(f"  - ...and {len(id_cols) - 5} more")

# Look for common ID columns that might be join keys
print("\nPotential join keys between files:")
for file_type1, id_cols1 in all_id_columns.items():
    for file_type2, id_cols2 in all_id_columns.items():
        if file_type1 != file_type2:
            common_cols = set(id_cols1).intersection(set(id_cols2))
            if common_cols:
                print(f"{file_type1} <-> {file_type2}: {', '.join(common_cols)}")
# Out:
# EXPLORING MEDICARE DATA STRUCTURE
# ==================================================
# OVERALL DATASET SUMMARY
# --------------------------------------------------
#
# Overall File Summary:
#                 filename  size_mb  columns
# 10           carrier.csv   443.66       96
# 5         outpatient.csv   320.09      162
# 11               dme.csv    36.49       87
# 8          inpatient.csv    33.89      197
# 14               snf.csv     9.49      160
# 17  beneficiary_2024.csv     5.09      185
# 7   beneficiary_2023.csv     4.84      185
# 3   beneficiary_2022.csv     4.56      185
# 12           hospice.csv     4.38       86
# 1   beneficiary_2021.csv     4.34      185
# 2   beneficiary_2020.csv     4.13      185
# 0   beneficiary_2019.csv     3.92      185
# 13  beneficiary_2018.csv     3.69      185
# 6   beneficiary_2017.csv     3.48      185
# 9   beneficiary_2016.csv     3.31      185
# 15  beneficiary_2025.csv     3.17      185
# 4   beneficiary_2015.csv     3.15      185
# 16               hha.csv     2.09       88
# Files by Type:
#                  file_type  filename  size_mb  columns
# 11          Carrier Claims         1   443.66     96.0
# 16       Outpatient Claims         1   320.09    162.0
# 12              DME Claims         1    36.49     87.0
# 15        Inpatient Claims         1    33.89    197.0
# 17  Skilled Nursing Claims         1     9.49    160.0
# 9         Beneficiary 2024         1     5.09    185.0
# 8         Beneficiary 2023         1     4.84    185.0
# 7         Beneficiary 2022         1     4.56    185.0
# 14          Hospice Claims         1     4.38     86.0
# 6         Beneficiary 2021         1     4.34    185.0
# 5         Beneficiary 2020         1     4.13    185.0
# 4         Beneficiary 2019         1     3.92    185.0
# 3         Beneficiary 2018         1     3.69    185.0
# 2         Beneficiary 2017         1     3.48    185.0
# 1         Beneficiary 2016         1     3.31    185.0
# 10        Beneficiary 2025         1     3.17    185.0
# 0         Beneficiary 2015         1     3.15    185.0
# 13      Home Health Claims         1     2.09     88.0
# DETAILED SCHEMA ANALYSIS
# ==================================================
#
# ==============================
# ANALYZING BENEFICIARY 2019
# ==============================
#
# File: beneficiary_2019.csv
# Size: 3.92 MB
# Total rows: 7,447
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              5      False
# 181  CST_SHR_GRP_CD_09   int64                2              5      False
# 182  CST_SHR_GRP_CD_10   int64                2              5      False
# 183  CST_SHR_GRP_CD_11   int64                2              5      False
# 184  CST_SHR_GRP_CD_12   int64                2              5      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2021
# ==============================
#
# File: beneficiary_2021.csv
# Size: 4.34 MB
# Total rows: 8,247
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2020
# ==============================
#
# File: beneficiary_2020.csv
# Size: 4.13 MB
# Total rows: 7,838
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              5      False
# 181  CST_SHR_GRP_CD_09   int64                2              5      False
# 182  CST_SHR_GRP_CD_10   int64                2              5      False
# 183  CST_SHR_GRP_CD_11   int64                2              5      False
# 184  CST_SHR_GRP_CD_12   int64                2              5      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2022
# ==============================
#
# File: beneficiary_2022.csv
# Size: 4.56 MB
# Total rows: 8,672
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2015
# ==============================
#
# File: beneficiary_2015.csv
# Size: 3.15 MB
# Total rows: 5,976
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                0              4      False
# 182  CST_SHR_GRP_CD_10   int64                0              4      False
# 183  CST_SHR_GRP_CD_11   int64                0              4      False
# 184  CST_SHR_GRP_CD_12   int64                0              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING OUTPATIENT CLAIMS
# ==============================
#
# File: outpatient.csv
# Size: 320.09 MB
# Total rows: 575,093
# Total columns: 162
#
# Schema:
#                          Column     Type     Sample Value  Unique Values  Has Nulls
# 0                       BENE_ID    int64  -10000010254618              1      False
# 1                        CLM_ID    int64  -10000930037832             10      False
# 2    NCH_NEAR_LINE_REC_IDENT_CD   object                W              1      False
# 3               NCH_CLM_TYPE_CD    int64               40              1      False
# 4                   CLM_FROM_DT   object      16-Mar-2015             10      False
# ..                          ...      ...              ...            ...        ...
# 157        REV_CNTR_STUS_IND_CD    int64                4              1      False
# 158            REV_CNTR_NDC_QTY  float64             NULL              0       True
# 159    REV_CNTR_NDC_QTY_QLFR_CD  float64             NULL              0       True
# 160           RNDRNG_PHYSN_UPIN   object                               1      False
# 161            RNDRNG_PHYSN_NPI    int64       9999995696              1      False
#
# [162 rows x 5 columns]
# Columns (first 20):
# 1. BENE_ID
# 2. CLM_ID
# 3. NCH_NEAR_LINE_REC_IDENT_CD
# 4. NCH_CLM_TYPE_CD
# 5. CLM_FROM_DT
# 6. CLM_THRU_DT
# 7. NCH_WKLY_PROC_DT
# 8. FI_CLM_PROC_DT
# 9. CLAIM_QUERY_CODE
# 10. PRVDR_NUM
# 11. CLM_FAC_TYPE_CD
# 12. CLM_SRVC_CLSFCTN_TYPE_CD
# 13. CLM_FREQ_CD
# 14. FI_NUM
# 15. CLM_MDCR_NON_PMT_RSN_CD
# 16. CLM_PMT_AMT
# 17. NCH_PRMRY_PYR_CLM_PD_AMT
# 18. NCH_PRMRY_PYR_CD
# 19. PRVDR_STATE_CD
# 20. ORG_NPI_NUM
# ...and 142 more columns
#
# ==============================
# ANALYZING BENEFICIARY 2017
# ==============================
#
# File: beneficiary_2017.csv
# Size: 3.48 MB
# Total rows: 6,614
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2023
# ==============================
#
# File: beneficiary_2023.csv
# Size: 4.84 MB
# Total rows: 9,180
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500              9      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING INPATIENT CLAIMS
# ==============================
#
# File: inpatient.csv
# Size: 33.89 MB
# Total rows: 58,067
# Total columns: 197
#
# Schema:
#                           Column     Type     Sample Value  Unique Values  Has Nulls
# 0                        BENE_ID    int64  -10000010254618              5      False
# 1                         CLM_ID    int64  -10000930037831              8      False
# 2     NCH_NEAR_LINE_REC_IDENT_CD   object                V              1      False
# 3                NCH_CLM_TYPE_CD    int64               60              1      False
# 4                    CLM_FROM_DT   object      25-Mar-2015              8      False
# ..                           ...      ...              ...            ...        ...
# 192     CLM_UNCOMPD_CARE_PMT_AMT  float64             NULL              0       True
# 193                 CLM_LINE_NUM    int64                1              2      False
# 194                     REV_CNTR    int64              450              2      False
# 195                     HCPCS_CD    int64            99221              5      False
# 196  REV_CNTR_DDCTBL_COINSRNC_CD  float64              3.0              1       True
#
# [197 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2016
# ==============================
#
# File: beneficiary_2016.csv
# Size: 3.31 MB
# Total rows: 6,289
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING CARRIER CLAIMS
# ==============================
#
# File: carrier.csv
# Size: 443.66 MB
# Total rows: 1,121,005
# Total columns: 96
#
# Schema:
#                             Column     Type     Sample Value  Unique Values  Has Nulls
# 0                          BENE_ID    int64  -10000010254618              1      False
# 1                           CLM_ID    int64  -10000930037915              1      False
# 2       NCH_NEAR_LINE_REC_IDENT_CD   object                O              1      False
# 3                  NCH_CLM_TYPE_CD    int64               71              1      False
# 4                      CLM_FROM_DT   object      28-Sep-2015              1      False
# 5                      CLM_THRU_DT   object      28-Sep-2015              1      False
# 6                 NCH_WKLY_PROC_DT   object      02-Oct-2015              1      False
# 7                CARR_CLM_ENTRY_CD    int64                1              1      False
# 8                      CLM_DISP_CD    int64                1              1      False
# 9                         CARR_NUM    int64              510              1      False
# 10             CARR_CLM_PMT_DNL_CD    int64                1              1      False
# 11                     CLM_PMT_AMT  float64           932.69              1      False
# 12       CARR_CLM_PRMRY_PYR_PD_AMT    int64                0              1      False
# 13                  RFR_PHYSN_UPIN  float64             NULL              0       True
# 14                   RFR_PHYSN_NPI    int64       9999971093              1      False
# 15    CARR_CLM_PRVDR_ASGNMT_IND_SW   object                A              1      False
# 16           NCH_CLM_PRVDR_PMT_AMT  float64           932.69              1      False
# 17            NCH_CLM_BENE_PMT_AMT    int64                0              1      False
# 18     NCH_CARR_CLM_SBMTD_CHRG_AMT  float64          1165.87              1      False
# 19          NCH_CARR_CLM_ALOWD_AMT  float64           932.69              1      False
# 20   CARR_CLM_CASH_DDCTBL_APLD_AMT  float64              0.0              1      False
# 21            CARR_CLM_HCPCS_YR_CD    int64                1              1      False
# 22          CARR_CLM_RFRNG_PIN_NUM  float64             NULL              0       True
# 23                 PRNCPAL_DGNS_CD   object            R4689              1      False
# 24            PRNCPAL_DGNS_VRSN_CD    int64                0              1      False
# 25                    ICD_DGNS_CD1   object            R4689              1      False
# 26               ICD_DGNS_VRSN_CD1    int64                0              1      False
# 27                    ICD_DGNS_CD2   object             E781              1      False
# 28               ICD_DGNS_VRSN_CD2    int64                0              1      False
# 29                    ICD_DGNS_CD3   object             J329              1      False
# 30               ICD_DGNS_VRSN_CD3    int64                0              1      False
# 31                    ICD_DGNS_CD4   object             E119              1      False
# 32               ICD_DGNS_VRSN_CD4    int64                0              1      False
# 33                    ICD_DGNS_CD5   object             D649              1      False
# 34               ICD_DGNS_VRSN_CD5    int64                0              1      False
# 35                    ICD_DGNS_CD6   object             E089              1      False
# 36               ICD_DGNS_VRSN_CD6    int64                0              1      False
# 37                    ICD_DGNS_CD7   object             B965              1      False
# 38               ICD_DGNS_VRSN_CD7    int64                0              1      False
# 39                    ICD_DGNS_CD8   object             E848              1      False
# 40               ICD_DGNS_VRSN_CD8    int64                0              1      False
# 41                    ICD_DGNS_CD9   object             E849              1      False
# 42               ICD_DGNS_VRSN_CD9    int64                0              1      False
# 43                   ICD_DGNS_CD10  float64             NULL              0       True
# 44              ICD_DGNS_VRSN_CD10  float64             NULL              0       True
# 45                   ICD_DGNS_CD11  float64             NULL              0       True
# 46              ICD_DGNS_VRSN_CD11  float64             NULL              0       True
# 47                   ICD_DGNS_CD12  float64             NULL              0       True
# 48              ICD_DGNS_VRSN_CD12  float64             NULL              0       True
# 49              CLM_CLNCL_TRIL_NUM  float64             NULL              0       True
# 50            CARR_CLM_BLG_NPI_NUM    int64       1063654341              1      False
# 51                        LINE_NUM    int64                1             10      False
# 52             CARR_PRFRNG_PIN_NUM  float64             NULL              0       True
# 53                  PRF_PHYSN_UPIN  float64             NULL              0       True
# 54                   PRF_PHYSN_NPI    int64       9999971093              1      False
# 55                     ORG_NPI_NUM    int64       1063654341              1      False
# 56         CARR_LINE_PRVDR_TYPE_CD    int64                0              1      False
# 57                         TAX_NUM    int64        999349929              1      False
# 58                  PRVDR_STATE_CD   object               AL              1      False
# 59                       PRVDR_ZIP    int64        361162501              1      False
# 60                    PRVDR_SPCLTY    int64                1              1      False
# 61                 PRTCPTNG_IND_CD    int64                1              1      False
# 62  CARR_LINE_RDCD_PMT_PHYS_ASTN_C    int64                0              1      False
# 63                   LINE_SRVC_CNT    int64               10              1      False
# 64           LINE_CMS_TYPE_SRVC_CD    int64                1              1      False
# 65           LINE_PLACE_OF_SRVC_CD    int64               11              1      False
# 66        CARR_LINE_PRCNG_LCLTY_CD    int64                1              1      False
# 67               LINE_1ST_EXPNS_DT   object      28-Sep-2015              1      False
# 68              LINE_LAST_EXPNS_DT   object      28-Sep-2015              1      False
# 69                        HCPCS_CD   object            96127              3       True
# 70               HCPCS_1ST_MDFR_CD  float64             NULL              0       True
# 71               HCPCS_2ND_MDFR_CD  float64             NULL              0       True
# 72                        BETOS_CD   object               Y1              2       True
# 73                LINE_NCH_PMT_AMT  float64            91.04              5      False
# 74               LINE_BENE_PMT_AMT    int64                0              1      False
# 75              LINE_PRVDR_PMT_AMT  float64            91.04              5      False
# 76        LINE_BENE_PTB_DDCTBL_AMT  float64              0.0              1      False
# 77          LINE_BENE_PRMRY_PYR_CD   object                               1      False
# 78      LINE_BENE_PRMRY_PYR_PD_AMT    int64                0              1      False
# 79               LINE_COINSRNC_AMT  float64            91.04              5      False
# 80             LINE_SBMTD_CHRG_AMT  float64            113.8              5      False
# 81             LINE_ALOWD_CHRG_AMT  float64            113.8              5      False
# 82               LINE_PRCSG_IND_CD   object                A              1      False
# 83              LINE_PMT_80_100_CD  float64             NULL              0       True
# 84         LINE_SERVICE_DEDUCTIBLE  float64             NULL              0       True
# 85              CARR_LINE_MTUS_CNT    int64               29              1      False
# 86               CARR_LINE_MTUS_CD  float64             NULL              0       True
# 87                LINE_ICD_DGNS_CD   object            R4689              2       True
# 88           LINE_ICD_DGNS_VRSN_CD    int64                0              1      False
# 89              HPSA_SCRCTY_IND_CD   object                               1      False
# 90                CARR_LINE_RX_NUM  float64             NULL              0       True
# 91           LINE_HCT_HGB_RSLT_NUM  float64              0.0              1      False
# 92            LINE_HCT_HGB_TYPE_CD   object               R1              1      False
# 93                     LINE_NDC_CD  float64             NULL              0       True
# 94          CARR_LINE_CLIA_LAB_NUM  float64             NULL              0       True
# 95      CARR_LINE_ANSTHSA_UNIT_CNT    int64                0              1      False
# Columns (first 20):
# 1. BENE_ID
# 2. CLM_ID
# 3. NCH_NEAR_LINE_REC_IDENT_CD
# 4. NCH_CLM_TYPE_CD
# 5. CLM_FROM_DT
# 6. CLM_THRU_DT
# 7. NCH_WKLY_PROC_DT
# 8. CARR_CLM_ENTRY_CD
# 9. CLM_DISP_CD
# 10. CARR_NUM
# 11. CARR_CLM_PMT_DNL_CD
# 12. CLM_PMT_AMT
# 13. CARR_CLM_PRMRY_PYR_PD_AMT
# 14. RFR_PHYSN_UPIN
# 15. RFR_PHYSN_NPI
# 16. CARR_CLM_PRVDR_ASGNMT_IND_SW
# 17. NCH_CLM_PRVDR_PMT_AMT
# 18. NCH_CLM_BENE_PMT_AMT
# 19. NCH_CARR_CLM_SBMTD_CHRG_AMT
# 20. NCH_CARR_CLM_ALOWD_AMT
# ...and 76 more columns
#
# ==============================
# ANALYZING DME CLAIMS
# ==============================
#
# File: dme.csv
# Size: 36.49 MB
# Total rows: 103,829
# Total columns: 87
#
# Schema:
#                            Column     Type     Sample Value  Unique Values  Has Nulls
# 0                         BENE_ID    int64  -10000010254618              1      False
# 1                          CLM_ID    int64  -10000930037927              7      False
# 2      NCH_NEAR_LINE_REC_IDENT_CD   object                M              1      False
# 3                 NCH_CLM_TYPE_CD    int64               82              1      False
# 4                     CLM_FROM_DT   object      25-Mar-2015              7      False
# 5                     CLM_THRU_DT   object      25-Mar-2015              7      False
# 6                NCH_WKLY_PROC_DT   object      24-Apr-2015              7      False
# 7               CARR_CLM_ENTRY_CD    int64                1              1      False
# 8                     CLM_DISP_CD    int64                1              1      False
# 9                        CARR_NUM    int64              510              1      False
# 10            CARR_CLM_PMT_DNL_CD    int64                1              1      False
# 11                    CLM_PMT_AMT  float64              0.0              2      False
# 12      CARR_CLM_PRMRY_PYR_PD_AMT  float64              0.0              2      False
# 13   CARR_CLM_PRVDR_ASGNMT_IND_SW   object                A              1      False
# 14          NCH_CLM_PRVDR_PMT_AMT  float64              0.0              2      False
# 15           NCH_CLM_BENE_PMT_AMT    int64                0              1      False
# 16    NCH_CARR_CLM_SBMTD_CHRG_AMT  float64              0.0              2      False
# 17         NCH_CARR_CLM_ALOWD_AMT  float64              0.0              2      False
# 18  CARR_CLM_CASH_DDCTBL_APLD_AMT  float64              0.0              1      False
# 19           CARR_CLM_HCPCS_YR_CD    int64                1              1      False
# 20                PRNCPAL_DGNS_CD   object           S134XX              5      False
# 21           PRNCPAL_DGNS_VRSN_CD    int64                0              1      False
# 22                   ICD_DGNS_CD1   object           S134XX              5      False
# 23              ICD_DGNS_VRSN_CD1    int64                0              1      False
# 24                   ICD_DGNS_CD2   object            R4689              6      False
# 25              ICD_DGNS_VRSN_CD2    int64                0              1      False
# 26                   ICD_DGNS_CD3   object             E781              5      False
# 27              ICD_DGNS_VRSN_CD3    int64                0              1      False
# 28                   ICD_DGNS_CD4   object             J329              4      False
# 29              ICD_DGNS_VRSN_CD4    int64                0              1      False
# 30                   ICD_DGNS_CD5   object             E119              5      False
# 31              ICD_DGNS_VRSN_CD5    int64                0              1      False
# 32                   ICD_DGNS_CD6   object             D649              5      False
# 33              ICD_DGNS_VRSN_CD6    int64                0              1      False
# 34                   ICD_DGNS_CD7   object             E849              4      False
# 35              ICD_DGNS_VRSN_CD7    int64                0              1      False
# 36                   ICD_DGNS_CD8   object             B965              4      False
# 37              ICD_DGNS_VRSN_CD8    int64                0              1      False
# 38                   ICD_DGNS_CD9   object             N469              5      False
# 39              ICD_DGNS_VRSN_CD9    int64                0              1      False
# 40                  ICD_DGNS_CD10   object             E849              3       True
# 41             ICD_DGNS_VRSN_CD10  float64              0.0              1       True
# 42                  ICD_DGNS_CD11   object             E089              3       True
# 43             ICD_DGNS_VRSN_CD11  float64              0.0              1       True
# 44                  ICD_DGNS_CD12   object             B965              3       True
# 45             ICD_DGNS_VRSN_CD12  float64              0.0              1       True
# 46                 RFR_PHYSN_UPIN  float64             NULL              0       True
# 47                  RFR_PHYSN_NPI    int64       9999841890              2      False
# 48             CLM_CLNCL_TRIL_NUM  float64             NULL              0       True
# 49                       LINE_NUM    int64                1              2      False
# 50                        TAX_NUM    int64        999562511              2      False
# 51                   PRVDR_SPCLTY    int64                1              1      False
# 52                PRTCPTNG_IND_CD    int64                2              4      False
# 53                  LINE_SRVC_CNT    int64               43              7      False
# 54          LINE_CMS_TYPE_SRVC_CD   object                R              2      False
# 55          LINE_PLACE_OF_SRVC_CD    int64               31              2      False
# 56              LINE_1ST_EXPNS_DT   object      25-Mar-2015              7      False
# 57             LINE_LAST_EXPNS_DT   object      18-Apr-2015              7      False
# 58                       HCPCS_CD   object            K0002              4      False
# 59              HCPCS_1ST_MDFR_CD  float64             NULL              0       True
# 60              HCPCS_2ND_MDFR_CD  float64             NULL              0       True
# 61                       BETOS_CD   object              D1D              2      False
# 62               LINE_NCH_PMT_AMT  float64              0.0              2      False
# 63              LINE_BENE_PMT_AMT    int64                0              1      False
# 64             LINE_PRVDR_PMT_AMT  float64              0.0              2      False
# 65       LINE_BENE_PTB_DDCTBL_AMT  float64              0.0              1      False
# 66         LINE_BENE_PRMRY_PYR_CD   object                               1      False
# 67     LINE_BENE_PRMRY_PYR_PD_AMT    int64                1              1      False
# 68      LINE_PRMRY_ALOWD_CHRG_AMT  float64              0.0              2      False
# 69            LINE_SBMTD_CHRG_AMT  float64              0.0              2      False
# 70            LINE_ALOWD_CHRG_AMT  float64              0.0              2      False
# 71              LINE_PRCSG_IND_CD   object                A              1      False
# 72             LINE_PMT_80_100_CD  float64             NULL              0       True
# 73        LINE_SERVICE_DEDUCTIBLE  float64             NULL              0       True
# 74          LINE_ICD_DGNS_VRSN_CD    int64                0              1      False
# 75                      PRVDR_NUM    int64            15037              2      False
# 76                      PRVDR_NPI    int64       1336780048              2      False
# 77      DMERC_LINE_PRCNG_STATE_CD    int64                1              1      False
# 78                 PRVDR_STATE_CD    int64                1              1      False
# 79      DMERC_LINE_SUPPLR_TYPE_CD    int64                8              5      False
# 80              HCPCS_3RD_MDFR_CD  float64             NULL              0       True
# 81              HCPCS_4TH_MDFR_CD  float64             NULL              0       True
# 82       DMERC_LINE_SCRN_SVGS_AMT    int64                0              1      False
# 83            DMERC_LINE_MTUS_CNT  float64             50.0              2       True
# 84             DMERC_LINE_MTUS_CD    int64                0              1      False
# 85          LINE_HCT_HGB_RSLT_NUM  float64              0.0              1      False
# 86                    LINE_NDC_CD  float64             NULL              0       True
# ==============================
# ANALYZING HOSPICE CLAIMS
# ==============================
#
# File: hospice.csv
# Size: 4.38 MB
# Total rows: 12,108
# Total columns: 86
#
# Schema:
#                          Column     Type     Sample Value  Unique Values  Has Nulls
# 0                       BENE_ID    int64  -10000010254676              1      False
# 1                        CLM_ID    int64  -10000930038434              1      False
# 2    NCH_NEAR_LINE_REC_IDENT_CD   object                V              1      False
# 3               NCH_CLM_TYPE_CD    int64               50              1      False
# 4                   CLM_FROM_DT   object      27-Oct-2019              1      False
# 5                   CLM_THRU_DT   object      16-Nov-2019              1      False
# 6              NCH_WKLY_PROC_DT   object      22-Nov-2019              1      False
# 7                FI_CLM_PROC_DT  float64             NULL              0       True
# 8                     PRVDR_NUM    int64            11517              1      False
# 9               CLM_FAC_TYPE_CD    int64                8              1      False
# 10     CLM_SRVC_CLSFCTN_TYPE_CD    int64                1              1      False
# 11                  CLM_FREQ_CD    int64                9              1      False
# 12                       FI_NUM  float64             NULL              0       True
# 13      CLM_MDCR_NON_PMT_RSN_CD   object                               1      False
# 14                  CLM_PMT_AMT  float64         11615.01              1      False
# 15     NCH_PRMRY_PYR_CLM_PD_AMT    int64                0              1      False
# 16             NCH_PRMRY_PYR_CD   object                               1      False
# 17               PRVDR_STATE_CD    int64                1              1      False
# 18                  ORG_NPI_NUM    int64       1861497935              1      False
# 19                AT_PHYSN_UPIN   object                               1      False
# 20                 AT_PHYSN_NPI    int64       9999872291              1      False
# 21          PTNT_DSCHRG_STUS_CD    int64                1              1      False
# 22             CLM_TOT_CHRG_AMT  float64         11615.01              1      False
# 23       NCH_PTNT_STATUS_IND_CD   object                A              1      False
# 24           CLM_UTLZTN_DAY_CNT    int64               20              1      False
# 25           NCH_BENE_DSCHRG_DT   object      22-Nov-2019              1      False
# 26              PRNCPAL_DGNS_CD   object             C188              1      False
# 27                 ICD_DGNS_CD1   object             Z733              1      False
# 28                 ICD_DGNS_CD2   object             Z608              1      False
# 29                 ICD_DGNS_CD3   object             P292              1      False
# 30                 ICD_DGNS_CD4   object            E8881              1      False
# 31                 ICD_DGNS_CD5   object             K621              1      False
# 32                 ICD_DGNS_CD6   object             K635              1      False
# 33                 ICD_DGNS_CD7   object            R7303              1      False
# 34                 ICD_DGNS_CD8   object             D649              1      False
# 35                 ICD_DGNS_CD9   object             E669              1      False
# 36                ICD_DGNS_CD10   object            R4689              1      False
# 37                ICD_DGNS_CD11  float64             NULL              0       True
# 38                ICD_DGNS_CD12  float64             NULL              0       True
# 39                ICD_DGNS_CD13  float64             NULL              0       True
# 40                ICD_DGNS_CD14  float64             NULL              0       True
# 41                ICD_DGNS_CD15  float64             NULL              0       True
# 42                ICD_DGNS_CD16  float64             NULL              0       True
# 43                ICD_DGNS_CD17  float64             NULL              0       True
# 44                ICD_DGNS_CD18  float64             NULL              0       True
# 45                ICD_DGNS_CD19  float64             NULL              0       True
# 46                ICD_DGNS_CD20  float64             NULL              0       True
# 47                ICD_DGNS_CD21  float64             NULL              0       True
# 48                ICD_DGNS_CD22  float64             NULL              0       True
# 49                ICD_DGNS_CD23  float64             NULL              0       True
# 50                ICD_DGNS_CD24  float64             NULL              0       True
# 51                ICD_DGNS_CD25  float64             NULL              0       True
# 52                FST_DGNS_E_CD   object              Y92              1      False
# 53               ICD_DGNS_E_CD1   object              X58              1      False
# 54               ICD_DGNS_E_CD2   object                               1      False
# 55               ICD_DGNS_E_CD3   object                               1      False
# 56               ICD_DGNS_E_CD4   object                               1      False
# 57               ICD_DGNS_E_CD5   object                               1      False
# 58               ICD_DGNS_E_CD6   object                               1      False
# 59               ICD_DGNS_E_CD7   object                               1      False
# 60               ICD_DGNS_E_CD8   object                               1      False
# 61               ICD_DGNS_E_CD9   object                               1      False
# 62              ICD_DGNS_E_CD10   object                               1      False
# 63              ICD_DGNS_E_CD11   object                               1      False
# 64              ICD_DGNS_E_CD12   object                               1      False
# 65        CLM_HOSPC_START_DT_ID   object      27-Oct-2019              1      False
# 66           BENE_HOSPC_PRD_CNT  float64             NULL              0       True
# 67             CLAIM_QUERY_CODE    int64                3              1      False
# 68                 CLM_LINE_NUM    int64                1             10      False
# 69                     REV_CNTR    int64              550              9      False
# 70                  REV_CNTR_DT   object      27-Oct-2019              1      False
# 71                     HCPCS_CD   object            99238              6       True
# 72            HCPCS_1ST_MDFR_CD  float64             NULL              0       True
# 73            HCPCS_2ND_MDFR_CD  float64             NULL              0       True
# 74            REV_CNTR_UNIT_CNT    int64                2              3      False
# 75            REV_CNTR_RATE_AMT  float64            459.1              1      False
# 76       REV_CNTR_PRVDR_PMT_AMT  float64           734.56              3      False
# 77        REV_CNTR_BENE_PMT_AMT    int64                0              1      False
# 78         REV_CNTR_PMT_AMT_AMT  float64           734.56              3      False
# 79        REV_CNTR_TOT_CHRG_AMT  float64            918.2              3      False
# 80      REV_CNTR_NCVRD_CHRG_AMT  float64              0.0              1      False
# 81  REV_CNTR_DDCTBL_COINSRNC_CD    int64                3              1      False
# 82             REV_CNTR_NDC_QTY  float64             NULL              0       True
# 83     REV_CNTR_NDC_QTY_QLFR_CD  float64             NULL              0       True
# 84            RNDRNG_PHYSN_UPIN   object                               1      False
# 85             RNDRNG_PHYSN_NPI    int64       9999872291              1      False
# ==============================
# ANALYZING BENEFICIARY 2018
# ==============================
#
# File: beneficiary_2018.csv
# Size: 3.69 MB
# Total rows: 7,003
# Total columns: 185
#
# Schema:
#                 Column    Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID   int64  -10000010254618             10      False
# 1           STATE_CODE   int64                1              1      False
# 2            COUNTY_CD   int64             1500             10      False
# 3               ZIP_CD   int64            36109             10      False
# 4        BENE_BIRTH_DT  object      16-Aug-1999             10      False
# ..                 ...     ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08   int64                2              4      False
# 181  CST_SHR_GRP_CD_09   int64                2              4      False
# 182  CST_SHR_GRP_CD_10   int64                2              4      False
# 183  CST_SHR_GRP_CD_11   int64                2              4      False
# 184  CST_SHR_GRP_CD_12   int64                2              4      False
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING SKILLED NURSING CLAIMS
# ==============================
#
# File: snf.csv
# Size: 9.49 MB
# Total rows: 12,549
# Total columns: 160
#
# Schema:
#                           Column     Type     Sample Value  Unique Values  Has Nulls
# 0                        BENE_ID    int64  -10000010254618              2      False
# 1                         CLM_ID    int64  -10000930038020              2      False
# 2     NCH_NEAR_LINE_REC_IDENT_CD   object                V              1      False
# 3                NCH_CLM_TYPE_CD    int64               20              1      False
# 4                    CLM_FROM_DT   object      25-Mar-2015              2      False
# ..                           ...      ...              ...            ...        ...
# 155  REV_CNTR_DDCTBL_COINSRNC_CD  float64              3.0              1       True
# 156             REV_CNTR_NDC_QTY  float64             NULL              0       True
# 157     REV_CNTR_NDC_QTY_QLFR_CD  float64             NULL              0       True
# 158            RNDRNG_PHYSN_UPIN   object                               1      False
# 159             RNDRNG_PHYSN_NPI  float64     9999841890.0              2       True
#
# [160 rows x 5 columns]
# ==============================
# ANALYZING BENEFICIARY 2025
# ==============================
#
# File: beneficiary_2025.csv
# Size: 3.17 MB
# Total rows: 10,001
# Total columns: 185
#
# Schema:
#                 Column     Type     Sample Value  Unique Values  Has Nulls
# 0              BENE_ID    int64  -10000010254618             10      False
# 1           STATE_CODE    int64                1              1      False
# 2            COUNTY_CD    int64             1500              9      False
# 3               ZIP_CD    int64            36109             10      False
# 4        BENE_BIRTH_DT   object      16-Aug-1999             10      False
# ..                 ...      ...              ...            ...        ...
# 180  CST_SHR_GRP_CD_08  float64             NULL              0       True
# 181  CST_SHR_GRP_CD_09  float64             NULL              0       True
# 182  CST_SHR_GRP_CD_10  float64             NULL              0       True
# 183  CST_SHR_GRP_CD_11  float64             NULL              0       True
# 184  CST_SHR_GRP_CD_12  float64             NULL              0       True
#
# [185 rows x 5 columns]
# ==============================
# ANALYZING HOME HEALTH CLAIMS
# ==============================
#
# File: hha.csv
# Size: 2.09 MB
# Total rows: 6,216
# Total columns: 88
#
# Schema:
#                          Column     Type     Sample Value  Unique Values  Has Nulls
# 0                       BENE_ID    int64  -10000010254850              1      False
# 1                        CLM_ID    int64  -10000930044285              1      False
# 2    NCH_NEAR_LINE_REC_IDENT_CD   object                W              1      False
# 3               NCH_CLM_TYPE_CD    int64               10              1      False
# 4                   CLM_FROM_DT   object      14-Oct-2021              1      False
# 5                   CLM_THRU_DT   object      09-Nov-2021              1      False
# 6              NCH_WKLY_PROC_DT   object      12-Nov-2021              1      False
# 7                FI_CLM_PROC_DT  float64             NULL              0       True
# 8                     PRVDR_NUM    int64            17879              1      False
# 9               CLM_FAC_TYPE_CD    int64                3              1      False
# 10     CLM_SRVC_CLSFCTN_TYPE_CD    int64                3              1      False
# 11                  CLM_FREQ_CD    int64                9              1      False
# 12                       FI_NUM  float64             NULL              0       True
# 13      CLM_MDCR_NON_PMT_RSN_CD   object                               1      False
# 14                  CLM_PMT_AMT  float64         11853.87              1      False
# 15     NCH_PRMRY_PYR_CLM_PD_AMT    int64                0              1      False
# 16             NCH_PRMRY_PYR_CD   object                               1      False
# 17               PRVDR_STATE_CD    int64                1              1      False
# 18                  ORG_NPI_NUM    int64       1225513278              1      False
# 19                AT_PHYSN_UPIN   object                               1      False
# 20                 AT_PHYSN_NPI    int64       9999873695              1      False
# 21          PTNT_DSCHRG_STUS_CD    int64                1              1      False
# 22               CLM_PPS_IND_CD   object                               1      False
# 23             CLM_TOT_CHRG_AMT  float64         14817.33              1      False
# 24              PRNCPAL_DGNS_CD   object             Z733              1      False
# 25                 ICD_DGNS_CD1   object             Z733              1      False
# 26                 ICD_DGNS_CD2   object             M179              1      False
# 27                 ICD_DGNS_CD3   object          T50901A              1      False
# 28                 ICD_DGNS_CD4   object             Z604              1      False
# 29                 ICD_DGNS_CD5   object             E669              1      False
# 30                 ICD_DGNS_CD6   object             Z558              1      False
# 31                 ICD_DGNS_CD7  float64             NULL              0       True
# 32                 ICD_DGNS_CD8  float64             NULL              0       True
# 33                 ICD_DGNS_CD9  float64             NULL              0       True
# 34                ICD_DGNS_CD10  float64             NULL              0       True
# 35                ICD_DGNS_CD11  float64             NULL              0       True
# 36                ICD_DGNS_CD12  float64             NULL              0       True
# 37                ICD_DGNS_CD13  float64             NULL              0       True
# 38                ICD_DGNS_CD14  float64             NULL              0       True
# 39                ICD_DGNS_CD15  float64             NULL              0       True
# 40                ICD_DGNS_CD16  float64             NULL              0       True
# 41                ICD_DGNS_CD17  float64             NULL              0       True
# 42                ICD_DGNS_CD18  float64             NULL              0       True
# 43                ICD_DGNS_CD19  float64             NULL              0       True
# 44                ICD_DGNS_CD20  float64             NULL              0       True
# 45                ICD_DGNS_CD21  float64             NULL              0       True
# 46                ICD_DGNS_CD22  float64             NULL              0       True
# 47                ICD_DGNS_CD23  float64             NULL              0       True
# 48                ICD_DGNS_CD24  float64             NULL              0       True
# 49                ICD_DGNS_CD25  float64             NULL              0       True
# 50                FST_DGNS_E_CD  float64             NULL              0       True
# 51               ICD_DGNS_E_CD1  float64             NULL              0       True
# 52               ICD_DGNS_E_CD2   object                               1      False
# 53               ICD_DGNS_E_CD3   object                               1      False
# 54               ICD_DGNS_E_CD4   object                               1      False
# 55               ICD_DGNS_E_CD5   object                               1      False
# 56               ICD_DGNS_E_CD6   object                               1      False
# 57               ICD_DGNS_E_CD7   object                               1      False
# 58               ICD_DGNS_E_CD8   object                               1      False
# 59               ICD_DGNS_E_CD9   object                               1      False
# 60              ICD_DGNS_E_CD10   object                               1      False
# 61              ICD_DGNS_E_CD11   object                               1      False
# 62              ICD_DGNS_E_CD12   object                               1      False
# 63          CLM_HHA_LUPA_IND_CD  float64             NULL              0       True
# 64              CLM_HHA_RFRL_CD  float64             NULL              0       True
# 65        CLM_HHA_TOT_VISIT_CNT    int64               28              1      False
# 66                 CLM_ADMSN_DT   object      14-Oct-2021              1      False
# 67             CLAIM_QUERY_CODE    int64                3              1      False
# 68                 CLM_LINE_NUM    int64                1             10      False
# 69                     REV_CNTR    int64              581              6      False
# 70                  REV_CNTR_DT   object      09-Nov-2021              9      False
# 71         REV_CNTR_1ST_ANSI_CD  float64             NULL              0       True
# 72        REV_CNTR_APC_HIPPS_CD  float64             NULL              0       True
# 73                     HCPCS_CD   object            99238             10      False
# 74            HCPCS_1ST_MDFR_CD  float64             NULL              0       True
# ...
# Beneficiary 2025 <-> Inpatient Claims: BENE_ID
# Beneficiary 2025 <-> Beneficiary 2016: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2025 <-> Carrier Claims: BENE_ID
# Beneficiary 2025 <-> DME Claims: BENE_ID
# Beneficiary 2025 <-> Hospice Claims: BENE_ID
# Beneficiary 2025 <-> Beneficiary 2018: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2025 <-> Skilled Nursing Claims: BENE_ID
# Beneficiary 2025 <-> Home Health Claims: BENE_ID
# Beneficiary 2025 <-> Beneficiary 2024: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Home Health Claims <-> Beneficiary 2019: BENE_ID
# Home Health Claims <-> Beneficiary 2021: BENE_ID
# Home Health Claims <-> Beneficiary 2020: BENE_ID
# Home Health Claims <-> Beneficiary 2022: BENE_ID
# Home Health Claims <-> Beneficiary 2015: BENE_ID
# Home Health Claims <-> Outpatient Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> Beneficiary 2017: BENE_ID
# Home Health Claims <-> Beneficiary 2023: BENE_ID
# Home Health Claims <-> Inpatient Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> Beneficiary 2016: BENE_ID
# Home Health Claims <-> Carrier Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> DME Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> Hospice Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> Beneficiary 2018: BENE_ID
# Home Health Claims <-> Skilled Nursing Claims: CLM_ID, BENE_ID, NCH_NEAR_LINE_REC_IDENT_CD
# Home Health Claims <-> Beneficiary 2025: BENE_ID
# Home Health Claims <-> Beneficiary 2024: BENE_ID
# Beneficiary 2024 <-> Beneficiary 2019: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Beneficiary 2021: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Beneficiary 2020: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Beneficiary 2022: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Beneficiary 2015: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Outpatient Claims: BENE_ID
# Beneficiary 2024 <-> Beneficiary 2017: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Beneficiary 2023: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Inpatient Claims: BENE_ID
# Beneficiary 2024 <-> Beneficiary 2016: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Carrier Claims: BENE_ID
# Beneficiary 2024 <-> DME Claims: BENE_ID
# Beneficiary 2024 <-> Hospice Claims: BENE_ID
# Beneficiary 2024 <-> Beneficiary 2018: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Skilled Nursing Claims: BENE_ID
# Beneficiary 2024 <-> Beneficiary 2025: PTD_CNTRCT_ID_12, PTD_PBP_ID_02, PTC_CNTRCT_ID_10, PTC_PBP_ID_01, SEX_IDENT_CD, PTC_CNTRCT_ID_11, PTC_PBP_ID_08, PTD_SGMT_ID_09, PTC_CNTRCT_ID_06, PTC_CNTRCT_ID_04, PTC_PBP_ID_02, PTD_PBP_ID_04, PTC_CNTRCT_ID_07, PTD_SGMT_ID_03, PTD_CNTRCT_ID_05, PTC_CNTRCT_ID_08, PTD_PBP_ID_09, PTC_CNTRCT_ID_09, PTD_PBP_ID_08, PTD_PBP_ID_06, PTC_PBP_ID_03, PTD_PBP_ID_01, PTD_PBP_ID_11, PTD_SGMT_ID_07, VALID_DEATH_DT_SW, PTC_PBP_ID_12, PTD_CNTRCT_ID_03, PTC_PBP_ID_10, PTD_SGMT_ID_10, PTC_PBP_ID_06, PTC_PBP_ID_09, PTC_PBP_ID_11, PTD_CNTRCT_ID_04, PTD_CNTRCT_ID_01, PTD_SGMT_ID_08, PTD_CNTRCT_ID_10, PTC_PBP_ID_05, PTD_SGMT_ID_06, PTC_CNTRCT_ID_05, PTD_PBP_ID_03, PTD_CNTRCT_ID_02, PTC_PBP_ID_04, PTD_PBP_ID_05, PTD_PBP_ID_12, PTD_SGMT_ID_04, PTD_SGMT_ID_05, PTD_PBP_ID_10, PTD_SGMT_ID_01, PTC_CNTRCT_ID_03, PTD_SGMT_ID_02, PTD_CNTRCT_ID_06, PTD_CNTRCT_ID_07, PTC_CNTRCT_ID_01, PTD_SGMT_ID_11, BENE_ID, PTC_CNTRCT_ID_12, PTD_CNTRCT_ID_09, PTD_PBP_ID_07, PTC_CNTRCT_ID_02, PTD_SGMT_ID_12, PTC_PBP_ID_07, PTD_CNTRCT_ID_11, PTD_CNTRCT_ID_08
# Beneficiary 2024 <-> Home Health Claims: BENE_ID
